.vodka ($23.99) .voyage ($5.99) .watch ($5.99) .webcam ($6.35) .website ($2.19) .wedding ($23.99) .whoswho ($22.99) .wiki ($22.99) .baby ($58.00) .monster ($9.99) .sydney ($58.00) .dev ($12.00) .app ($13.99) .melbourne ($58.00) .win ($2.75) .wine ($5.99) .works ($3.99) .world ($1.99) .work ($6.29) .ws ($5.99) .wtf ($3.99) .yoga ($23.99) .zone ($3.99) .travel ($89.45)

# %%
from collections import OrderedDict

l = {}
for i in range(1, len(x.split(' '))):
    if(x.split(' ')[i].strip() == ''):
        continue
    if(x.split(' ')[i].strip()[0] == '.'):
        l[x.split(' ')[i].strip()] = float(x.split(' ')[i+1].strip())

# for i in sorted(l.keys()):  
#      print(i, l[i]) 

for i in l:
    print(i, l[i])
# Out:
# .com 8.99
# .net 11.79
# .org 10.79
# .club 1.99
# .biz 13.19
# .life 2.99
# .icu 1.49
# .info 2.29
# .top 0.99
# .store 8.99
# .xyz 0.99
# .ac 35.99
# .academy 23.99
# .accountant 11.5
# .accountants 5.99
# .actor 5.99
# .agency 1.99
# .airforce 5.99
# .apartments 37.99
# .archi 51.95
# .army 5.99
# .art 10.69
# .asia 4.39
# .associates 5.99
# .attorney 11.39
# .auction 5.99
# .audio 114.99
# .band 3.99
# .bar 54.99
# .bargains 3.99
# .beer 23.99
# .best 2.75
# .bid 2.75
# .bike 3.99
# .bingo 35.99
# .bio 51.95
# .black 40.45
# .blackfriday 114.99
# .blog 22.99
# .blue 12.84
# .boston 11.99
# .boutique 8.89
# .builders 23.99
# .business 6.59
# .buzz 27.99
# .ca 8.99
# .cab 23.99
# .cafe 5.99
# .camera 37.99
# .camp 37.99
# .capital 5.99
# .cards 23.99
# .care 5.99
# .careers 37.99
# .casa 6.29
# .cash 3.99
# .casino 16.59
# .catering 23.99
# .cc 9.99
# .center 3.99
# .charity 22.0
# .chat 21.99
# .cheap 5.99
# .christmas 53.99
# .church 5.99
# .city 3.99
# .claims 5.99
# ...

# %%
x.split(' ')
# Out:
# ['',
#  '.com',
#  '8.99',
#  '.net',
#  '11.79',
#  '.org',
#  '10.79',
#  '.club',
#  '1.99',
#  '.biz',
#  '13.19',
#  '',
#  '.life',
#  '2.99',
#  '.icu',
#  '1.49',
#  '.info',
#  '2.29',
#  '.top',
#  '0.99',
#  '',
#  '.store',
#  '8.99',
#  '',
#  '.xyz',
#  '0.99',
#  '',
#  '.ac',
#  '35.99',
#  '',
#  '.academy',
#  '23.99',
#  '',
#  '.accountant',
#  '11.50',
#  '',
#  '.accountants',
#  '5.99',
#  '',
#  '.actor',
#  '5.99',
#  '',
#  '.agency',
#  '1.99',
#  '',
#  '.airforce',
#  '5.99',
#  '',
#  '.apartments',
#  '37.99',
#  '',
#  '.archi',
#  '51.95',
#  '',
#  '.army',
#  '5.99',
#  '',
#  '.art',
#  '10.69',
#  '',
#  '.asia',
#  '4.39',
#  '',
#  '.associates',
#  '5.99',
#  '',
#  '.attorney',
#  '11.39',
#  '',
#  '.auction',
#  '5.99',
#  '',
#  '.audio',
#  '114.99',
#  '',
#  '.band',
#  '3.99',
#  '',
#  '.bar',
#  '54.99',
#  '',
#  '.bargains',
#  '3.99',
#  '',
#  '.beer',
#  '23.99',
#  '',
#  '.best',
#  '2.75',
#  '',
#  '.bid',
#  '2.75',
#  '',
# ...
